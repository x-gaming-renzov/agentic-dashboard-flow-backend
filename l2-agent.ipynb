# %%
from src.agents.generate_l2.agent import generate_l2_metrics, register_metrics
# Out:
# Status:  Initialising nodes
# Status:  Initialising ChatOpenAI
# Status:  ChatOpenAI initialised
# Status:  Initialising nodes
# Status:  Initialising ChatOpenAI
# Status:  ChatOpenAI initialised

# %%
#l2s = generate_l2_metrics(focus_metric="avg timespend per session per player mins", l1_metrics=['1', '2', '3'], remarks="Geneerate L2 metrics for avg timespend per session per player mins for PvP players segment.")

# %%
#l2s

# %%
#metrics_ids = register_metrics(l2s)

# %%
metrics_ids = ['1', '2', '3', '4', '5', '6', '7']

# %%
from src.agents.data_agent.agent import generate_metric_plot

# %%
bs64 = generate_metric_plot(metrics_ids)

# %%
len(bs64)
# Out:
# 6

# %%
from langchain_core.messages import HumanMessage
