# %%
from src.agents.experiment_agent.agent import get_experiment_ready_offer
# Out:
# Status:  Initialising nodes
# Status:  Initialising ChatOpenAI
# Status:  ChatOpenAI initialised
# Status:  Initialising nodes
# Status:  Initialising ChatOpenAI
# Status:  ChatOpenAI initialised

# %%
#graph = get_graph()

# %%
#state = ExperimentState(chat_id="3", segment_id=['1', '2'])

# %%
#out = graph.invoke(state)

# %%
offer_ids = get_experiment_ready_offer(chat_id="3", segment_id=['1', '2'])
# Out:
# Chat:  {'_id': '3', 'segments_ids': ['1', '2'], 'metric_ids': ['6', '3', '4', '7', '1', '2', '5'], 'human_remark': 'Explore personalised in-app offers for my segemnts', 'idea': ['2'], 'offers': "# Personalised In-App Purchase Bundles Report\n\n## **1. Casual PvP Players**\n\n### Bundle Name: **Casual Player Boost Bundle**\n- **Bundle Price:** $4.99\n- **Bundle Items:**\n  - 500 in-game currency\n  - 3 Health Potions\n  - 2 PvP Battle Boosts (increased damage for limited time)\n  - 5 Resource Packs (gather resources quickly)\n  \n- **Bundle Description:**\n  This bundle is tailored for the more laid-back PvP player looking to enhance their gameplay experience without diving too deep into competitive challenges. With resource packs to ease gathering and health potions to ensure survival, this bundle promotes fun, casual sessions with friendly PvP encounters.\n\n- **Segments:** Casual PvP Players\n\n- **Bundle Recommendation:**\n  Given the casual nature of this segment, we recommend of
# ...

# %%
offer_ids
# Out:
# ['b89ed459c1e145c4943e80147550a49b', 'eed967404fd64cc7b16cc3ed7edb1b45']

# %%
from src.agents.experiment_agent.utils.cohorts import get_cohorts

# %%
cohorts = get_cohorts(segment_id='1')
# Out:
# Status:  Instructions generated
# Status:  Query generated
# Status:  Query executed
# ...

# %%
cohorts
# Out:
# ['00000000-0000-0000-0009-01f0fd96bea7',
#  '00000000-0000-0000-0009-01f178f269de',
#  '00000000-0000-0000-0009-01f2507e0aed',
#  '00000000-0000-0000-0009-01f94cf4c707',
#  '00000000-0000-0000-0009-01fcb62e2c15',
#  '00000000-0000-0000-0009-01fd048d56ca',
#  '00000000-0000-0000-0009-01fe1068df67',
#  '01f3c93a-a4b3-394f-af39-501fb6411172',
#  '0311bc16-89ad-33dc-b8a7-9512fdd8d76d',
#  '03bdbe15-3ce2-3b0e-94c7-bfda1ceb846f',
#  '0737abc0-52f1-36f0-8de2-34f90e5228ed',
#  '0c306540-a3e1-3ed4-ac99-c3abd6e826d4',
#  '0f9dea9e-d46a-3db1-86ac-2c3924a02b37',
#  '102ffb9b-6bfb-35ad-96e9-4795e00b5cec',
#  '1ee63135-fdf0-30b1-bdad-bf3f217ea6bb',
#  '263467ae-c516-3e37-b472-a85fd255c382',
#  '2ca5ba0d-f03d-3d96-b988-56100124da17',
#  '32ea8223-98f5-3cee-88f5-e5b7b0f1ffac',
#  '34a59ede-a6eb-3e5c-afe3-771731816899',
#  '34f74dc1-3d19-3d02-88e7-bb596dac2c88',
#  '3599ea0b-9f74-37d9-8e97-a0236c15828a',
#  '3bb0e7da-ac66-3374-bdda-6c913d91fa0d',
#  '3f082ec8-234e-377b-b310-1e31a162ff41',
# ...
